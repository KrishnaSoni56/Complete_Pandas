# %% [markdown]
# # Attrition Data Analysis

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("D:\\Feature_csv_Files\\Attrition.csv")

df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# # Department Name of employee that layoffs

# %%
# filter yes category of attrition column
attr_data = df[df["Attrition"] == "Yes"]

# No of employee layoff with respective department 
department_attrition = attr_data.groupby('Department').size().reset_index(name = "Employee_Count")
department_attrition
# Out:
#                Department  Employee_Count
# 0         Human Resources              12
# 1  Research & Development             133
# 2                   Sales              92

# %% [markdown]
# # Education Field of employee that layoff

# %%
edu_attr = attr_data.groupby('EducationField').size().reset_index(name = "Employee_Count")
edu_attr
# Out:
#      EducationField  Employee_Count
# 0   Human Resources               7
# 1     Life Sciences              89
# 2         Marketing              35
# 3           Medical              63
# 4             Other              11
# 5  Technical Degree              32

# %% [markdown]
# # Marital Status of Layoffs Employee

# %%
Marital_Status_attr = attr_data.groupby('MaritalStatus').size().reset_index(name = "Employee_Count")
Marital_Status_attr
# Out:
#   MaritalStatus  Employee_Count
# 0      Divorced              33
# 1       Married              84
# 2        Single             120

# %% [markdown]
# # Overtime Employee layoff

# %%
Overtime_Employee_attr = attr_data.groupby('OverTime').size().reset_index(name = "Employee_Count")
Overtime_Employee_attr
# Out:
#   OverTime  Employee_Count
# 0       No             110
# 1      Yes             127

# %% [markdown]
# # Job Satisfation of Attrition Employees

# %%
Job_satisfation_attr = attr_data.groupby('JobSatisfaction').size().reset_index(name = "Employee_Count")
Job_satisfation_attr
# Out:
#    JobSatisfaction  Employee_Count
# 0                1              66
# 1                2              46
# 2                3              73
# 3                4              52

# %% [markdown]
# # No of years spend by employee that layoff

# %%
Emp_YearsAtCompany = attr_data.groupby('YearsAtCompany').size().reset_index(name= "Count")
Emp_YearsAtCompany
# Out:
#     YearsAtCompany  Count
# 0                0     16
# 1                1     59
# 2                2     27
# 3                3     20
# 4                4     19
# 5                5     21
# 6                6      9
# 7                7     11
# 8                8      9
# 9                9      8
# 10              10     18
# 11              11      2
# 12              13      2
# 13              14      2
# 14              15      1
# 15              16      1
# 16              17      1
# 17              18      1
# 18              19      1
# 19              20      1
# 20              21      1
# 21              22      1
# 22              23      1
# 23              24      1
# 24              31      1
# 25              32      1
# 26              33      1
# 27              40      1

# %% [markdown]
# # Employee layoff due to Distance

# %%
Emp_distance = attr_data.groupby("DistanceFromHome").size().reset_index(name= "Count")
Emp_distance
# Out:
#     DistanceFromHome  Count
# 0                  1     26
# 1                  2     28
# 2                  3     14
# 3                  4      9
# 4                  5     10
# 5                  6      7
# 6                  7     11
# 7                  8     10
# 8                  9     18
# 9                 10     11
# 10                11      4
# 11                12      6
# 12                13      6
# 13                14      4
# 14                15      5
# 15                16      7
# 16                17      5
# 17                18      4
# 18                19      3
# 19                20      4
# 20                21      3
# 21                22      6
# 22                23      5
# 23                24     12
# 24                25      6
# 25                26      3
# 26                27      3
# 27                28      2
# 28                29      5

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.io as pio
import plotly.graph_objects as go
pio.templates.default = "plotly_dark"

# %%
print(df.isnull().sum())
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
sns.distplot(df['Age'] )
plt.title('Distribution of Age') 
plt.show()
# Out:
# C:\Users\soni2\AppData\Local\Temp\ipykernel_18260\4229231238.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %%
# Calculate the count of attrition by department
attrition_by = attr_data.groupby(['Department']).size().reset_index(name='Count')

# Create a donut chart
fig = go.Figure(data=[go.Pie(
    labels=attrition_by['Department'],
    values=attrition_by['Count'],
    hole=0.4,
    marker=dict(colors=['#3CAEA3', '#F6D55C']),
    textposition='inside'
)])

# Update the layout
fig.update_layout(title='Attrition by Department', font=dict(size=16), legend=dict(
    orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1
))

# Show the chart
fig.show()

# %%
attrition_by = attr_data.groupby(['EducationField']).size().reset_index(name='Count')

# Create a donut chart
fig = go.Figure(data=[go.Pie(
    labels=attrition_by['EducationField'],
    values=attrition_by['Count'],
    hole=0.4,
    marker=dict(colors=['#3CAEA3', '#F6D55C']),
    textposition='inside'
)])

# Update the layout
fig.update_layout(title='Attrition by Educational Field', font=dict(size=16), legend=dict(
    orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1
))

# Show the chart
fig.show()

# %%
attrition_by = attr_data.groupby(['YearsSinceLastPromotion']).size().reset_index(name='Count')
attrition_by
# Out:
#     YearsSinceLastPromotion  Count
# 0                         0    110
# 1                         1     49
# 2                         2     27
# 3                         3      9
# 4                         4      5
# 5                         5      2
# 6                         6      6
# 7                         7     16
# 8                         9      4
# 9                        10      1
# 10                       11      2
# 11                       13      2
# 12                       14      1
# 13                       15      3

# %%
attrition_by = attr_data.groupby(['Gender']).size().reset_index(name='count')
attrition_by

# Create a donut chart
fig = go.Figure(data=[go.Pie(
    labels=attrition_by['Gender'],
    values=attrition_by['count'],
    hole=0.4,
    marker=dict(colors=['#3CAEA3', '#F6D55C']),
    textposition='inside'
)])

# Update the layout
fig.update_layout(title='Attrition by Gender', font=dict(size=16), legend=dict(
    orientation="h", yanchor="bottom", y=1.02, xanchor="right", x=1
))

# Show the chart
fig.show()

# %%
import plotly.express as px

# %%
fig = px.scatter(df, x="Age", y="MonthlyIncome", color="Attrition", trendline="ols")
fig.update_layout(title="Age vs. Monthly Income by Attrition")
fig.show()

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...
