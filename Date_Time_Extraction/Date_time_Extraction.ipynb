# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("D:\\csv files\\click.csv")
df1 = pd.read_csv("D:\\csv files\\ecommerce_data.csv")

# %%
df1.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-16        1897       26       2
# 1  2019-12-16        4850       26       4
# 2  2019-12-16        2466       26       1
# 3  2019-12-16         637       26       1
# 4  2019-12-16        3497       26     184

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523684 entries, 0 to 523683
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        523684 non-null  object
#  1   product_id  523684 non-null  int64
#  2   city_id     523684 non-null  int64
#  3   orders      523684 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 16.0+ MB

# %% [markdown]
# # Working With Dates

# %%
df1['date'] = pd.to_datetime(df1["date"])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523684 entries, 0 to 523683
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        523684 non-null  datetime64[ns]
#  1   product_id  523684 non-null  int64
#  2   city_id     523684 non-null  int64
#  3   orders      523684 non-null  int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 16.0 MB

# %%
df1["Date_Year"] = df1["date"].dt.year

# %%
df1.sample(15)
# Out:
#              date  product_id  city_id  orders  Date_Year
# 494221 2018-11-09        5445       27       4       2018
# 29981  2019-10-14        6906       18     195       2019
# 85013  2019-11-29        2261       25      11       2019
# 319531 2019-07-02        2250       14       9       2019
# 293802 2019-06-13        6159       26       1       2019
# 486794 2018-09-26        2705       18      36       2018
# 399910 2019-06-09        7366       12       1       2019
# 215214 2019-03-04        5148       16       1       2019
# 32600  2019-10-15        6256       30       5       2019
# 151506 2018-09-15        6077       17       1       2018
# 470805 2018-12-08        3992       16       5       2018
# 149017 2018-09-05        3960       30      15       2018
# 317794 2019-08-10        2372       23       3       2019
# 414739 2018-11-08        4756        2      16       2018
# 474058 2018-12-18        4431       16       1       2018

# %% [markdown]
# # Extract Month number

# %%
df1["Date_month"] = df1['date'].dt.month

# %%
df1.sample(16)
# Out:
#              date  product_id  city_id  orders  Date_Year  Date_month
# 236330 2019-03-22        1488       17       1       2019           3
# 341374 2019-08-16        5656        0       4       2019           8
# 25691  2019-10-07        7350       16      54       2019          10
# 129945 2018-08-29        3429       25      14       2018           8
# 491836 2018-10-10        5778       24      18       2018          10
# 26024  2019-10-24        1475       16       9       2019          10
# 99498  2019-12-02        2267        1      22       2019          12
# 517192 2018-09-27        1685        1       1       2018           9
# 10675  2019-10-15        4395        2       3       2019          10
# 377333 2019-08-15        5219       24       6       2019           8
# 214195 2019-04-07        2029       16       1       2019           4
# 407556 2018-12-18           8       26       1       2018          12
# ...

# %% [markdown]
# # Extract Month Names

# %%
df1["Date_month_name"] = df1["date"].dt.month_name()

# %%
df1.sample(5)
# Out:
#              date  product_id  city_id  orders  Date_Year  Date_month  \
# 252751 2019-10-28        2981       26     692       2019          10
# 64634  2019-06-01        2018       29       8       2019           6
# 433670 2018-11-22         300       14     494       2018          11
# 160697 2018-08-13        2012        8     114       2018           8
# 65588  2019-05-02        3904        1      15       2019           5
#
#        Date_month_name
# 252751         October
# 64634             June
# 433670        November
# 160697          August
# 65588              May

# %% [markdown]
# # Extract Week no

# %%
df1['Date_Week'] = df1['date'].dt.dayofweek

# %%
df1.sample(5)
# Out:
#              date  product_id  city_id  orders  Date_Year  Date_month  \
# 10567  2019-10-07        3520        2      36       2019          10
# 226511 2019-03-04        2698       24       1       2019           3
# 152444 2018-09-17        6174        3       3       2018           9
# 242134 2019-01-23        4152       28       5       2019           1
# 66249  2019-05-28        4865       12       1       2019           5
#
#        Date_month_name  Date_Week
# 10567          October          0
# 226511           March          0
# 152444       September          0
# 242134         January          2
# 66249              May          1

# %% [markdown]
# # Extract Week Days

# %%
df1['Date_weekname'] = df1['date'].dt.day_name()

# %%
df1.sample(8)
# Out:
#              date  product_id  city_id  orders  Date_Year  Date_month  \
# 438952 2018-10-14        1295       14       1       2018          10
# 400676 2018-12-11        2807       26      73       2018          12
# 413846 2018-09-30         492        2       1       2018           9
# 238434 2019-01-27        1480        3       1       2019           1
# 465600 2018-11-03        6357        4      19       2018          11
# 477989 2018-10-19        1371       22     168       2018          10
# 262674 2019-11-07        2208       14     179       2019          11
# 116606 2018-09-14        2411       23       1       2018           9
#
#        Date_month_name  Date_Week Date_weekname
# 438952         October          6        Sunday
# 400676        December          1       Tuesday
# 413846       September          6        Sunday
# 238434         January          6        Sunday
# 465600        November          5      Saturday
# ...

# %% [markdown]
# # Extract Days

# %%
df1['Date_day'] = df1['date'].dt.day

# %%
df1.sample(5)
# Out:
#              date  product_id  city_id  orders  Date_Year  Date_month  \
# 274928 2019-11-17        5412       16       2       2019          11
# 287433 2019-11-09        7018        1       1       2019          11
# 356746 2019-08-10         955       16      12       2019           8
# 285251 2019-11-14        1981       28       2       2019          11
# 290106 2019-06-06        2012        8      58       2019           6
#
#        Date_month_name  Date_Week Date_weekname  Date_day
# 274928        November          6        Sunday        17
# 287433        November          5      Saturday         9
# 356746          August          5      Saturday        10
# 285251        November          3      Thursday        14
# 290106            June          3      Thursday         6

# %%
df1['Date_is_weekend'] = np.where(df1["Date_weekname"].isin(['Sunday' , 'Saturday']) , 1, 0)

# %%
df1.sample(10)
# Out:
#              date  product_id  city_id  orders  Date_Year  Date_month  \
# 280538 2019-10-30        4921       24       2       2019          10
# 438283 2018-09-25        6761       14       5       2018           9
# 340977 2019-09-18        3553        0       3       2019           9
# 161744 2019-04-21        2270       26     452       2019           4
# 374272 2019-08-11        1932       18       4       2019           8
# 33792  2019-10-10        3782       20      11       2019          10
# 99539  2019-11-20        4271        7       1       2019          11
# 110622 2018-08-06        1114       13     763       2018           8
# 522316 2018-11-06        1404       21       1       2018          11
# 24106  2019-10-08         696       25       5       2019          10
#
#        Date_month_name  Date_Week Date_weekname  Date_day  Date_is_weekend
# 280538         October          2     Wednesday        30                0
# ...

# %%
df1['Date_is_weekend'].value_counts()
# Out:
# 0    373640
# 1    150044
# Name: Date_is_weekend, dtype: int64

# %%
df1['date_week'] = df1['date'].dt.isocalendar().week

# %%
df1.sample(10)
# Out:
#              date  product_id  city_id  orders  Date_Year  Date_month  \
# 352759 2019-08-06         715        4       6       2019           8
# 463235 2018-12-15        4717       25       1       2018          12
# 28988  2019-10-17        7214       22       3       2019          10
# 75920  2019-11-21        1232       14       2       2019          11
# 424801 2018-12-16        6493       13       1       2018          12
# 474069 2018-12-31        4431       16       1       2018          12
# 195907 2019-04-21        2578        0       3       2019           4
# 410036 2018-10-22        6286       26       3       2018          10
# 393524 2019-06-27        3042       28       1       2019           6
# 11619  2019-10-11         354       13       1       2019          10
#
#        Date_month_name  Date_Week Date_weekname  Date_day  Date_is_weekend  \
# 352759          August          1       Tuesday         6                0
# ...

# %%
df1['Quater'] = df1['date'].dt.quarter

# %%
df1.sample(10)
# Out:
#              date  product_id  city_id  orders  Date_Year  Date_month  \
# 205157 2019-03-21        2691       25       3       2019           3
# 204949 2019-01-22        1896       25       4       2019           1
# 321301 2019-07-17        6361       14      32       2019           7
# 382367 2019-06-21        1738       20       1       2019           6
# 482807 2019-01-07        6818       22       2       2019           1
# 74235  2019-12-11        5485       13       1       2019          12
# 67790  2019-11-20        6159       26       2       2019          11
# 218659 2019-04-15        6460       22       1       2019           4
# 54537  2019-06-01        7350       16      36       2019           6
# 60626  2019-05-22        1115       30       1       2019           5
#
#        Date_month_name  Date_Week Date_weekname  Date_day  Date_is_weekend  \
# 205157           March          3      Thursday        21                0
# ...

# %% [markdown]
# # Extract time elapsed between dates

# %%
import datetime

# %%
today = datetime.datetime.today()

# %%
today
# Out:
# datetime.datetime(2023, 8, 27, 13, 45, 58, 999366)

# %%
today - df1['date']
# Out:
# 0        1350 days 13:45:58.999366
# 1        1350 days 13:45:58.999366
# 2        1350 days 13:45:58.999366
# 3        1350 days 13:45:58.999366
# 4        1350 days 13:45:58.999366
#                     ...
# 523679   1698 days 13:45:58.999366
# 523680   1696 days 13:45:58.999366
# 523681   1692 days 13:45:58.999366
# 523682   1691 days 13:45:58.999366
# 523683   1690 days 13:45:58.999366
# Name: date, Length: 523684, dtype: timedelta64[ns]

# %%
today
# Out:
# datetime.datetime(2023, 8, 27, 13, 45, 58, 999366)

# %%
(today - df1['date']).dt.days
# Out:
# 0         1350
# 1         1350
# 2         1350
# 3         1350
# 4         1350
#           ...
# 523679    1698
# 523680    1696
# 523681    1692
# 523682    1691
# 523683    1690
# Name: date, Length: 523684, dtype: int64

# %%
df1.sample(10)
# Out:
#              date  product_id  city_id  orders  Date_Year  Date_month  \
# 93731  2019-12-01        7382       30      36       2019          12
# 27588  2019-10-10        3884       16       8       2019          10
# 512939 2019-01-10        3238       29       1       2019           1
# 139683 2018-07-13        2235       16       2       2018           7
# 107045 2018-07-24        1935        2      69       2018           7
# 222594 2019-04-23        6906       18     271       2019           4
# 355321 2019-07-19        2117       16       1       2019           7
# 180888 2019-04-23        1573       13       2       2019           4
# 281120 2019-11-12        4864       27       5       2019          11
# 436599 2019-01-05         722       14       2       2019           1
#
#        Date_month_name  Date_Week Date_weekname  Date_day  Date_is_weekend  \
# 93731         December          6        Sunday         1                1
# ...

# %% [markdown]
# # Click Date TIme Extraction

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  10000 non-null  float64
#  1   Age                       10000 non-null  float64
#  2   Area Income               10000 non-null  float64
#  3   Daily Internet Usage      10000 non-null  float64
#  4   Ad Topic Line             10000 non-null  object
#  5   City                      10000 non-null  object
#  6   Gender                    10000 non-null  object
#  7   Country                   10000 non-null  object
#  8   Timestamp                 10000 non-null  datetime64[ns]
#  9   Clicked on Ad             10000 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(4)
# memory usage: 781.4+ KB

# %% [markdown]
# # Year Extract

# %%
df['Timestamp_year'] = df['Timestamp'].dt.year

# %%
df.sample(10)
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 7016                     40.47  35.0     25603.93                236.87
# 4068                     83.71  31.0     61840.26                207.17
# 3519                     85.62  29.0     53431.35                216.49
# 1772                     70.39  27.0     39193.45                198.50
# 7444                     65.77  41.0     48335.20                137.24
# 9300                     65.77  23.0     56457.01                172.81
# 1816                     46.61  43.0     66025.11                167.86
# 3940                     68.01  33.0     56782.18                227.37
# 982                      83.40  34.0     20592.99                160.03
# 9632                     89.05  43.0     57868.44                163.48
#
#                                  Ad Topic Line             City  Gender  \
# 7016             Optional multi-state hardware       Karenmouth  Female
# ...

# %% [markdown]
# # Month Extract

# %%
df['Timestamp_month'] = df['Timestamp'].dt.month

# %%
df.sample(4)
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 6776                     75.03  34.0     59785.94                203.44
# 1055                     59.51  29.0     69646.35                200.71
# 8645                     53.92  28.0     59448.44                217.37
# 1137                     50.63  39.0     37334.78                210.60
#
#                                    Ad Topic Line           City  Gender  \
# 6776  Function-based incremental standardization  New Tinamouth  Female
# 1055             Digitized content-based circuit   West Shannon  Female
# 8645                Organized global flexibility    Kennedyfurt    Male
# 1137               Operative full-range forecast     New Brandy    Male
#
#                 Country           Timestamp  Clicked on Ad  Timestamp_year  \
# 6776  Brunei Darussalam 2016-06-21 03:14:41              0            2016
# 1055            Burundi 2016-06-12 21:21:53              0            2016
# ...

# %% [markdown]
# # Days Extract

# %%
df['Timestamp_day'] = df['Timestamp'].dt.day

# %%
df.sample(5)
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 7768                     51.24  45.0     59610.81                202.25
# 2748                     68.01  38.0     32593.59                259.76
# 781                      76.20  34.0     59785.94                243.61
# 9867                     79.52  41.0     57846.68                158.80
# 24                       86.06  35.0     73889.99                158.29
#
#                                     Ad Topic Line             City  Gender  \
# 7768            De-engineered actuating hierarchy      Lake Hailey  Female
# 2748  Pre-emptive systematic budgetary management      East Carlos  Female
# 781                 Operative full-range forecast    Patriciahaven    Male
# 9867                     Robust uniform framework        West Lisa  Female
# 24     De-engineered attitude-oriented projection  South Adamhaven    Male
#
#        Country           Timestamp  Clicked on Ad  Timestamp_year  \
# ...

# %%
df['Timestamp_weekname'] = df['Timestamp'].dt.day_name()

# %%
df.sample(5)
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 5008                     59.05  38.0     52736.33                123.13
# 8195                     89.05  34.0     40183.75                160.03
# 4676                     36.08  45.0     59610.81                137.24
# 418                      34.30  34.0     34191.23                168.34
# 8168                     51.24  36.0     59240.24                140.46
#
#                                Ad Topic Line           City  Gender  \
# 5008  Virtual bandwidth-monitored initiative   Kevinchester  Female
# 8195              Cloned explicit middleware      Kingshire    Male
# 4676          Enhanced homogeneous moderator    Wintersfort    Male
# 418               Cloned explicit middleware      Kingshire    Male
# 8168         Up-sized incremental encryption  North Brandon  Female
#
#                      Country           Timestamp  Clicked on Ad  \
# ...

# %%
df["Timestamp_hours"] = df['Timestamp'].dt.hour

# %%
df.sample(5)
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 2834                     37.00  30.0     57877.15                113.69
# 8096                     82.07  48.0     43974.49                123.13
# 7752                     71.33  39.0     59677.64                207.17
# 1675                     68.18  28.0     53058.91                217.37
# 190                      80.47  33.0     52736.33                113.12
#
#                                     Ad Topic Line           City  Gender  \
# 2834  Cross-platform logistical pricing structure  New Tinamouth    Male
# 8096        Integrated coherent pricing structure    Burgessside    Male
# 7752               Optional full-range projection    East Connie    Male
# 1675                            Inverse local hub      Jamiefort  Female
# 190       Adaptive contextually-based methodology   South George    Male
#
#         Country           Timestamp  Clicked on Ad  Timestamp_year  \
# ...

# %%
df["Timestamp_minute"] = df['Timestamp'].dt.minute

# %%
df.sample(5)
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 3795                     57.24  52.0     33951.63                117.75
# 1604                     59.05  50.0     43974.49                231.49
# 7719                     39.96  25.0     50506.44                241.03
# 1772                     70.39  27.0     39193.45                198.50
# 8696                     51.87  19.0     51067.54                195.69
#
#                                       Ad Topic Line            City  Gender  \
# 3795        Adaptive contextually-based methodology     Taylorhaven    Male
# 1604  Function-based context-sensitive secured line     Burgessside    Male
# 7719           Digitized contextually-based product  West Aprilport  Female
# 1772             Decentralized needs-based analyzer      Jordantown    Male
# 8696                   Managed client-server access        Penatown    Male
#
#         Country           Timestamp  Clicked on Ad  Timestamp_year  \
# ...

# %%
df["Timestamp_seconds"] = df['Timestamp'].dt.second

# %%
df.sample(5)
# Out:
#       Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  \
# 3699                     41.73  28.0     53058.91                182.65
# 6195                     55.60  24.0     52252.91                172.83
# 787                      56.39  40.0     40468.53                167.22
# 3594                     59.05  48.0     52736.33                148.61
# 7304                     82.07  48.0     53922.43                123.13
#
#                                           Ad Topic Line               City  \
# 3699                Down-sized bandwidth-monitored core        Amandahaven
# 6195                    Devolved human-resource circuit           Lisafort
# 787   Vision-oriented attitude-oriented Internet sol...       Williamsport
# 3594      Function-based context-sensitive secured line        Burgessside
# 7304           Cross-platform 4thgeneration focus group  Port Michaelmouth
#
#       Gender  Country           Timestamp  Clicked on Ad  Timestamp_year  \
# ...
